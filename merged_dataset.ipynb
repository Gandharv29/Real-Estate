# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\Arun\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('houses_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                        property_name property_type               society  \
# 0    3 BHK Flat in Sector 56 Gurgaon          flat       kiran residency
# 1  1 Bedroom House for sale in Sohna         house           independent
# 2    4 BHK Flat in Sector 65 Gurgaon          flat        m3m golfestate
# 3      3 BHK Flat in Nirvana Country          flat       the close north
# 4    3 BHK Flat in Sector 90 Gurgaon          flat  dlf new town heights
#
#    price  price_per_sqft     area  \
# 0   1.54          8324.0   1850.0
# 1   0.07          2525.0    277.0
# 2  13.20         12000.0  11000.0
# 3   2.70         10364.0   2605.0
# 4   1.25          6476.0   1930.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 2000(185.81 sq.m.)Built Up...        3         4
# 1                          Plot area 33(27.59 sq.m.)        1         1
# 2                 Carpet area: 11000 (1021.93 sq.m.)        4         4
# 3  Super Built up area 2605(242.01 sq.m.)Built Up...        3         3
# 4  Super Built up area 1930(179.3 sq.m.)Built Up ...        3         3
#
#   balcony           additionalRoom  \
# 0      3+             Servant Room
# 1       0            not available
# 2       3             Servant Room
# 3      3+             Servant Room
# 4      3+  Pooja Room,Servant Room
#
#                                           address  floorNum facing  \
# 0  Sector 56, Sector 56 Gurgaon, Gurgaon, Haryana       5.0  South
# 1                         Sohna, Gurgaon, Haryana       1.0    NaN
# 2             Sector 65 Gurgaon, Gurgaon, Haryana      13.0  North
# 3          002, Nirvana Country, Gurgaon, Haryana       6.0   East
# 4      55665, Sector 90 Gurgaon, Gurgaon, Haryana       6.0   West
#
#       agePossession                                    nearbyLocations  \
# 0      10+ Year Old  ['Sector metro station', 'Sector metro station...
# 1   1 to 5 Year Old                                                NaN
# 2  5 to 10 Year Old  ['Sector 54 Chowk Metro Station', 'Sahara Mall...
# 3  5 to 10 Year Old  ['Sector 55-56 Metro Station', 'Eros City Squa...
# 4   1 to 5 Year Old  ['Manish Gallexie 91', 'NH-8 IMT Manesar', 'RH...
#
#                                          description  \
# 0  Situated in sector 56 gurgaon, kiran residency...
# 1  Interested to sell independent house/villa.Pla...
# 2  4 bedroom 11000 sq.Ft. Middle floor penthouse ...
# 3  Check out this 3 bhk apartment for sale in the...
# 4  This beautiful 3 bhk flat in sector 90 gurgaon...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Ge...
# 1                                                 []
# 2  ['4 Fan', '8 Light', 'No AC', 'No Bed', 'No Ch...
# 3  ['5 Fan', '15 Light', 'No AC', 'No Bed', 'No C...
# 4                                                NaN
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Lift(s)', 'H...
# 1                                                NaN
# 2  ['Power Back-up', 'Intercom Facility', 'Lift(s...
# 3  ['Centrally Air Conditioned', 'Water purifier'...
# 4  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Lifestyle5 out of 5...
# 1  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2  ['Green Area5 out of 5', 'Construction5 out of...
# 3  ['Green Area5 out of 5', 'Construction4 out of...
# 4  ['Green Area5 out of 5', 'Construction4 out of...

# %%
df.to_csv('gurgaon_properties.csv',index=False)
