# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\Arun\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('houses_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                    property_name property_type  \
# 0               2 BHK Flat in Sector 104 Gurgaon          flat
# 1               2 BHK Flat in Sector 113 Gurgaon          flat
# 2                4 BHK Flat in Sector 90 Gurgaon          flat
# 3  3 Bedroom House for sale in Sector 38 Gurgaon         house
# 4                2 BHK Flat in Sector 99 Gurgaon          flat
#
#                    society  price  price_per_sqft    area  \
# 0         puri emerald bay   1.50          9678.0  1550.0
# 1  la vida by tata housing   1.50         11755.0  1276.0
# 2        dlf regal gardens   1.65          7449.0  2215.0
# 3              independent   3.50         24306.0  1440.0
# 4           assotech blith   0.82          6007.0  1365.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                Super Built up area 1550(144 sq.m.)        2         2
# 1             Super Built up area 1276(118.54 sq.m.)        2         2
# 2  Super Built up area 2215(205.78 sq.m.)Built Up...        4         4
# 3                    Carpet area: 160 (133.78 sq.m.)        3         3
# 4                 Built Up area: 1365 (126.81 sq.m.)        2         2
#
#   balcony additionalRoom                                            address  \
# 0       2         Others  Puri Emerald Bay, Sector 104 Gurgaon, Gurgaon,...
# 1       2  not available              Sector 113 Gurgaon , Gurgaon, Haryana
# 2      3+  not available          1256, Sector 90 Gurgaon, Gurgaon, Haryana
# 3       2  not available     Sector 38, Sector 38 Gurgaon, Gurgaon, Haryana
# 4       3  not available  Assotech Blith, Sector 99, Gurgaon, Sector 99 ...
#
#    floorNum facing       agePossession  \
# 0       7.0    NaN  Under Construction
# 1      13.0    NaN     0 to 1 Year Old
# 2      15.0   East     1 to 5 Year Old
# 3       1.0   East     1 to 5 Year Old
# 4       0.0    NaN           undefined
#
#                                      nearbyLocations  \
# 0  ['Sector-21 Metro Dwarka', 'Gurgaon Dreamz Mal...
# 1  ['Dwarka Sector 21', 'Pacific D21 Mall', 'Bajg...
# 2  ['SS Omnia, Sector 86', 'Numberdar market, IMT...
# 3                                                NaN
# 4  ['Shri Balaji Hospital and Trauma Center', 'Sh...
#
#                                          description  \
# 0  Residential apartment for sell.Located on 7th ...
# 1                    Top floor with delhi green view
# 2  This 4 bhk apartment is available for sale in ...
# 3  Best in class property available at sector 38 ...
# 4  Looking for a 2 bhk apartment for sale in gurg...
#
#                                       furnishDetails  \
# 0                                                NaN
# 1                                                NaN
# 2  ['1 Exhaust Fan', '4 Geyser', '10 Light', '6 A...
# 3                                                NaN
# 4  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
#
#                                             features  \
# 0  ['Intercom Facility', 'Lift(s)', 'Feng Shui / ...
# 1  ['Security / Fire Alarm', 'Intercom Facility',...
# 2  ['Water purifier', 'Security / Fire Alarm', 'P...
# 3                                                NaN
# 4                                                NaN
#
#                                               rating
# 0  ['Management5 out of 5', 'Green Area5 out of 5...
# 1                                                NaN
# 2  ['Green Area5 out of 5', 'Construction4.5 out ...
# 3  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 4  ['Safety4.5 out of 5', 'Lifestyle4 out of 5', ...

# %%
df.to_csv('gurgaon_properties',index=False)
